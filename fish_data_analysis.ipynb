# %%
import pandas as pd

# %%
data = pd.read_csv('fish_csv_data.csv')
data.head()
# Out:
#   Species  Weight  Length  Diagonal   Height   Width
# 0   Bream   242.0    25.4      30.0  11.5200  4.0200
# 1   Bream   290.0    26.3      31.2  12.4800  4.3056
# 2   Bream   340.0    26.5      31.1  12.3778  4.6961
# 3   Bream   363.0    29.0      33.5  12.7300  4.4555
# 4   Bream   430.0    29.0      34.0  12.4440  5.1340

# %%
data.columns
# Out:
# Index(['Species', 'Weight', 'Length', 'Diagonal', 'Height', 'Width'], dtype='object')

# %%
targets = data['Species'].to_numpy()
print(targets)
# Out:
# ['Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream'
#  'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream'
#  'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream'
#  'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Bream' 'Roach'
#  'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach'
#  'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach' 'Roach'
#  'Roach' 'Whitefish' 'Whitefish' 'Whitefish' 'Whitefish' 'Whitefish'
#  'Whitefish' 'Parkki' 'Parkki' 'Parkki' 'Parkki' 'Parkki' 'Parkki'
#  'Parkki' 'Parkki' 'Parkki' 'Parkki' 'Parkki' 'Perch' 'Perch' 'Perch'
#  'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch'
#  'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch'
#  'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch'
#  'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch' 'Perch'
# ...

# %%
inputs = data[['Weight', 'Length', 'Diagonal', 'Height', 'Width']].to_numpy()

# %%
print(inputs)
# Out:
# [[2.42000e+02 2.54000e+01 3.00000e+01 1.15200e+01 4.02000e+00]
#  [2.90000e+02 2.63000e+01 3.12000e+01 1.24800e+01 4.30560e+00]
#  [3.40000e+02 2.65000e+01 3.11000e+01 1.23778e+01 4.69610e+00]
#  [3.63000e+02 2.90000e+01 3.35000e+01 1.27300e+01 4.45550e+00]
#  [4.30000e+02 2.90000e+01 3.40000e+01 1.24440e+01 5.13400e+00]
#  [4.50000e+02 2.97000e+01 3.47000e+01 1.36024e+01 4.92740e+00]
#  [5.00000e+02 2.97000e+01 3.45000e+01 1.41795e+01 5.27850e+00]
#  [3.90000e+02 3.00000e+01 3.50000e+01 1.26700e+01 4.69000e+00]
#  [4.50000e+02 3.00000e+01 3.51000e+01 1.40049e+01 4.84380e+00]
#  [5.00000e+02 3.07000e+01 3.62000e+01 1.42266e+01 4.95940e+00]
#  [4.75000e+02 3.10000e+01 3.62000e+01 1.42628e+01 5.10420e+00]
#  [5.00000e+02 3.10000e+01 3.62000e+01 1.43714e+01 4.81460e+00]
#  [5.00000e+02 3.15000e+01 3.64000e+01 1.37592e+01 4.36800e+00]
#  [3.40000e+02 3.20000e+01 3.73000e+01 1.39129e+01 5.07280e+00]
#  [6.00000e+02 3.20000e+01 3.72000e+01 1.49544e+01 5.17080e+00]
# ...

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(inputs, targets)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
train_scaled = ss.fit_transform(train_input)
test_scaled = ss.transform(test_input)
print(train_scaled.shape, test_scaled.shape)
# Out:
# (119, 5) (40, 5)

# %%
print(train_scaled)
# Out:
# [[ 0.26028328  0.18302838  0.39970059  1.17846282  0.26778763]
#  [-0.40008904 -0.12172548 -0.24294221 -0.50091856 -0.10312388]
#  [-0.83565377 -0.64552116 -0.71832181 -0.85881989 -0.30509363]
#  [ 0.76610037  0.59254137  0.78704693  1.46916549  0.96351402]
#  [-0.17528145  0.9258659   0.82226024 -0.65436837 -0.31578614]
#  [-0.95086766 -1.00741636 -1.00002824 -0.91129617 -1.00206748]
#  [ 1.45457365  1.02110148  1.20080325  2.23819342  1.33127717]
#  [-1.12509355 -1.73120677 -1.7659176  -1.7468674  -1.99605566]
#  [ 0.78015085  0.73539474  0.64619372  0.39539127  1.39917465]
#  [-0.83565377 -0.74075674 -0.80635507 -0.81902967 -0.56646625]
#  [ 0.56939373  0.449688    0.61098041  1.50764497  0.37138623]
#  [ 0.82230227  0.40207021  0.60217709  1.34497319  0.40922586]
#  [-0.90028595 -0.85503944 -0.83276505 -0.83679483 -0.79243476]
#  [ 0.8616436   0.68777695  0.86627687  1.71455412  0.79772061]
#  [-1.08940534 -1.37883512 -1.44899786 -1.47900899 -1.45026211]
# ...

# %%
from sklearn.linear_model import LogisticRegression

train_score = []
test_score = []

domain = range(1, 50)
for i in domain:
    lr = LogisticRegression(C=i)
    lr.fit(train_scaled, train_target)
    train_score.append(lr.score(train_scaled, train_target))
    test_score.append(lr.score(test_scaled, test_target))

# %%
import matplotlib.pyplot as plt

plt.plot(domain, train_score, label='train')
plt.plot(domain, test_score, label='test')
plt.xlabel('domain')
plt.ylabel('score')
plt.show()

# %%
import numpy as np

train_score = np.array(train_score)
test_score = np.array(test_score)

tt = np.abs(train_score - test_score)

# %%
plt.plot(domain, tt)
plt.xlabel('domain')
plt.ylabel('score')
plt.show()

# %%
tt[2:10].argmin()
# Out:
# np.int64(2)

# %%
tt[4]
# Out:
# np.float64(0.007563025210084007)

# %%
domain[4]
# Out:
# 5

# %%
lr = LogisticRegression(C=5)
lr.fit(train_scaled, train_target)
print(lr.score(train_scaled, train_target))
print(lr.score(test_scaled, test_target))
# Out:
# 0.907563025210084
# 0.9

# %%
data.head()
# Out:
#   Species  Weight  Length  Diagonal   Height   Width
# 0   Bream   242.0    25.4      30.0  11.5200  4.0200
# 1   Bream   290.0    26.3      31.2  12.4800  4.3056
# 2   Bream   340.0    26.5      31.1  12.3778  4.6961
# 3   Bream   363.0    29.0      33.5  12.7300  4.4555
# 4   Bream   430.0    29.0      34.0  12.4440  5.1340

# %%
sample = [[500, 30, 35, 13, 5]]
sample_scaled = ss.transform(sample)
print(lr.predict(sample_scaled))
# Out:
# ['Bream']
